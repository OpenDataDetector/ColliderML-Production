# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import uproot
import sys
import seaborn as sns
from tqdm import tqdm
import networkx as nx

import atlasify as atl
from particle import Particle
atl.ATLAS = "ColliderML"

sys.path.append("/global/cfs/cdirs/m4958/usr/danieltm/ColliderML/software/OtherLibraries/pyedm4hep")
from pyedm4hep import EDM4hepEvent, EDM4hepEventBatch

# %% [markdown]
# ## Roadmap
#
# 1. Load an edm4hep file
# 2. Load the particles and tracker hits
# 3. Inspect with the susy particles (e.g. neutralinos) are present, and other susy particles (especially those that cause large radius tracks)

# %% [markdown]
# ## Loading

# %%
# Load the edm4hep file with uproot
edm_input_file = "/global/cfs/cdirs/m4958/data/ColliderML/simulation/hard_scatter/susy_rpv/v1/runs/0/edm4hep.root"
event = EDM4hepEventBatch(edm_input_file, events=(0, 1), condense_calo=False)

root_file = uproot.open(edm_input_file)["events"]

# Print the keys of the root file
print(root_file.keys())
# Out:
# ---------------------------------------------------------------------------
# KeyInFileError                            Traceback (most recent call last)
# Cell In[8], line 5
#       2 edm_input_file = "/global/cfs/cdirs/m4958/data/ColliderML/simulation/hard_scatter/susy_rpv/v1/runs/0/edm4hep.root"
#       3 event = EDM4hepEventBatch(edm_input_file, events=(0, 1), condense_calo=False)
# ----> 5 root_file = uproot.open(edm_input_file)["events"]
#       7 # Print the keys of the root file
#       8 print(root_file.keys())
#
# File ~/.conda/envs/collider-env/lib/python3.11/site-packages/uproot/reading.py:2116, in ReadOnlyDirectory.__getitem__(self, where)
#    2113     return step
#    2115 else:
# -> 2116     return self.key(where).get()
#
# File ~/.conda/envs/collider-env/lib/python3.11/site-packages/uproot/reading.py:2064, in ReadOnlyDirectory.key(self, where)
#    2062     return last
#    2063 elif cycle is None:
# -> 2064     raise uproot.KeyInFileError(
# ...

# %%
uproot.open(edm_input_file).keys()
# Out:
# []

# %%
tracker_hits = event.get_tracker_hits_df()
calo_hits = event.get_calo_hits_df()
particles = event.get_particles_df()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 tracker_hits = event.get_tracker_hits_df()
#       2 calo_hits = event.get_calo_hits_df()
#       3 particles = event.get_particles_df()
#
# File /global/cfs/cdirs/m4958/usr/danieltm/ColliderML/software/OtherLibraries/pyedm4hep/pyedm4hep/event_batch.py:95, in EDM4hepEventBatch.get_tracker_hits_df(self, event_id)
#      94 def get_tracker_hits_df(self, event_id: Optional[int] = None) -> pd.DataFrame:
# ---> 95     self._ensure_loaded("tracker_hits")
#      96     df = self._tracker_hits_df
#      97     if event_id is None:
#
# File /global/cfs/cdirs/m4958/usr/danieltm/ColliderML/software/OtherLibraries/pyedm4hep/pyedm4hep/event_batch.py:175, in EDM4hepEventBatch._ensure_loaded(self, which)
#     173     self._load_particles_and_links()
#     174 elif which == "tracker_hits":
# ...

# %%
particles
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 particles
#
# NameError: name 'particles' is not defined
