# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import uproot
import sys
import seaborn as sns
from tqdm import tqdm
import networkx as nx

import atlasify as atl
from particle import Particle
atl.ATLAS = "ColliderML"

sys.path.append("/global/cfs/cdirs/m4958/usr/danieltm/ColliderML/software/OtherLibraries/pyedm4hep")
from pyedm4hep import EDM4hepEvent, EDM4hepEventBatch

# %% [markdown]
# ## Roadmap
#
# 1. Load an edm4hep file
# 2. Load the particles and tracker hits
# 3. Inspect with the susy particles (e.g. neutralinos) are present, and other susy particles (especially those that cause large radius tracks)

# %% [markdown]
# ## Loading

# %%
# Load the edm4hep file with uproot
edm_input_file = "/global/cfs/cdirs/m4958/data/ColliderML/simulation/hard_scatter/susy_rpv/v1/runs/0/edm4hep.root"
event = EDM4hepEventBatch(edm_input_file, events=(0, 1), condense_calo=False)

# %%
tracker_hits = event.get_tracker_hits_df()
calo_hits = event.get_calo_hits_df()
particles = event.get_particles_df()

# %%
particles.PDG.unique()
# Out:
# array([      2212,         -2,          2,         21,          1,
#              2101,         -1,        211,        221,        311,
#              3122,       -211,        111,      -3122,       -321,
#               113,          3,         -3,       -313,       -213,
#               321,        333,       3322,      -3112,        213,
#              2114,       -311,      -3222,        223,       -323,
#              2112,      -2212,       3212,      -3212,       1114,
#             -1114,        313,        310,         22,      -2112,
#               130,    1000023,        323,       2224,       2214,
#             -2214,        331,       3222,       3224,      -3324,
#             -3312,         11,        -11,   -1000014,         14,
#          -2000011, 1000020030, 1000010020, 1000140280,        -13,
#               -14,         13, 1000110240, 1000020040, 1000140290,
#        1000060120, 1000010030, 1000120240, 1000130270], dtype=int32)

# %%
tracker_hits
# Out:
#       event_id  subentry             cellID        time            x  \
# 0            0         0  60077547270377222    0.144050    30.402032
# 1            0         1   6649970879241750    0.292478    63.335321
# 2            0         2  70070007727796262    0.481834   102.399987
# 3            0         3  59497099620140854    0.716374   145.373103
# 4            0         4   6122261132484118    0.302634    63.569908
# ...        ...       ...                ...         ...          ...
# 6375         0       654     15663745823054    9.288465 -1020.603412
# 6376         0       655     15685221708110    9.306403 -1022.580861
# 6377         0       656     15706696548686    9.345511 -1026.930085
# 6378         0       657     15668040794446    9.363808 -1028.907160
# 6379         0       658     16849156837710  602.358215  -337.763211
#
#                y            z                detector  particle_id  \
# 0      -9.939022     2.208908      PixelBarrelReadout          335
# 1     -24.882639   -17.336838      PixelBarrelReadout          335
# 2     -49.665924   -41.886809      PixelBarrelReadout          335
# 3     -87.735785   -71.972332      PixelBarrelReadout          335
# 4     -24.275881   -18.914919      PixelBarrelReadout         1783
# ...          ...          ...                     ...          ...
# 6375   66.962789  2604.500000  LongStripEndcapReadout         1759
# 6376   66.846928  2609.500000  LongStripEndcapReadout         1759
# 6377   66.588938  2620.500000  LongStripEndcapReadout         1759
# 6378   66.468849  2625.500000  LongStripEndcapReadout         1759
# 6379 -885.664803  2604.475820  LongStripEndcapReadout         5130
#
#                 r            R       phi     theta       eta
# 0       31.985429    32.061612 -0.315967  1.501846  0.069005
# 1       68.047840    70.221610 -0.374346  1.820263 -0.252096
# 2      113.808881   121.272281 -0.451591  1.923456 -0.360205
# 3      169.796664   184.420507 -0.543005  1.971713 -0.412109
# 4       68.047422    70.627373 -0.364786  1.841919 -0.274506
# ...           ...          ...       ...       ...       ...
# 6375  1022.797800  2798.130731  3.076076  0.374201  1.664344
# 6376  1024.763450  2803.503233  3.076315  0.374202  1.664342
# 6377  1029.086724  2815.322315  3.076841  0.374203  1.664339
# 6378  1031.051915  2820.694649  3.077081  0.374203  1.664338
# 6379   947.885083  2771.602502 -1.935137  0.349043  1.735481
#
# [6380 rows x 14 columns]
